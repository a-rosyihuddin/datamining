# %% [markdown]
# # Linier Regression

# %% [markdown]
# # Membuat Dataset dari library sklearn dataset

# %%
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=150, n_features=1, noise=5)
pyplot.scatter(abs(X_test), abs(y_test))
pyplot.show()

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)
# Out:
# 0.9833730164214328

# %% [markdown]
# Koefisien (m)

# %%
reg.coef_
# Out:
# array([44.20894572])

# %% [markdown]
# Konstanta (c)

# %%
reg.intercept_
# Out:
# 0.15791549645698844

# %%
pred = reg.predict([[3]])

# %%
pyplot.scatter(X_test, y_test)
pyplot.plot([0,10],[100,10], color='red')

# %%
Xbaru, ybaru = make_regression(n_samples=100, n_features=1, noise=5)

# %%
pyplot.scatter(Xbaru, ybaru)
pyplot.show()

# %%
reg.score(Xbaru,ybaru)
# Out:
# 0.6899551497424482
